# %%
import pandas as pd
import numpy as np

# %%
NODE_TOTAL=30
ITERATION=9

MSG_NO_ROUTE = "ping: connect: No route to host"

# %%
# Create an empty DataFrame with columns
columns = ['Iter', 'tx_node_id', 'pingRoutes', 'pingLoss']
df = pd.DataFrame(columns=columns)
# Out:
#       Iter  tx_node_id  rx_node_id  LossRate  next_hop pingRoutes  pingLoss
# 0        0           0           1      0.00         1         []       NaN
# 1        0           0           2      0.00         2         []       NaN
# 2        0           0           3      0.00         3         []       NaN
# 3        0           0           4     59.11         2         []       NaN
# 4        0           0           5     93.09         3         []       NaN
# ...    ...         ...         ...       ...       ...        ...       ...
# 4345     9          26          28      0.00        28         []       NaN
# 4346     9          26          29      0.00        29         []       NaN
# 4347     9          27          28      0.00        28         []       NaN
# 4348     9          27          29      0.00        29         []       NaN
# 4349     9          28          29      0.00        29         []       NaN
#
# [4350 rows x 7 columns]

# %%
i = 0
# Open a ping log files for reading
for tx_node_id in range(NODE_TOTAL):
    for iter in range(ITERATION):
        with open('/tmp/seedsim/tc_command/{}/pingLog/log_{}.txt'.format(tx_node_id, iter), 'r') as file:
            # Read the entire file
            content = file.read()
            routes = []
            loss = np.nan
            if MSG_NO_ROUTE not in content:
#                 print(tx_node_id, iter)
#                 print(content.split('statistics')[1])            
                loss = int(content.split('statistics')[1].split('\n')[1].split(' packet loss')[0].split(',')[-1].replace('%', '').strip())
                if loss != 100:
                    for next_hop in content.split('RR:')[1].split('\n'):
                        if next_hop == "": break
                        routes.append(str(int(next_hop.strip().split('.')[-1])%100))
#                     print(routes)
                    routes = ' '.join(routes)
            df.loc[i] = {'Iter': iter, 'tx_node_id': tx_node_id, 'pingRoutes': routes, 'pingLoss': loss}
            i = i+1
# Out:
# ['0', '6', '11', '29', '29', '11', '7', '0']
# ['0', '6', '11', '29', '29', '11', '7', '0']
# ['0', '6', '11', '29', '29', '11', '7', '0']
# ['0', '6', '11', '29', '29', '11', '7', '0']
# ['0', '6', '11', '29', '29', '11', '7', '0']
# ['0', '6', '11', '29', '29', '11', '7', '0']
# ['0', '6', '11', '29', '29', '11', '6', '0']
# ['0', '6', '5', '29', '29', '23', '3', '0']
# ['0', '2', '29', '29', '2', '0']
# ['1', '5', '11', '29', '29', '11', '7', '1']
# ['1', '5', '11', '29', '29', '11', '7', '1']
# ['1', '5', '29', '29', '5', '1']
# ['1', '5', '29', '29', '5', '1']
# ['1', '5', '29', '29', '5', '1']
# ['1', '5', '29', '29', '5', '1']
# ['1', '2', '29', '29', '2', '1']
# ['2', '4', '11', '29', '29', '11', '4', '2']
# ['2', '10', '11', '29', '29', '20', '10', '2']
# ['2', '10', '11', '29', '29', '20', '10', '2']
# ['2', '3', '5', '29', '29', '25', '3', '2']
# ['2', '3', '5', '29', '29', '25', '3', '2']
# ['2', '3', '5', '29', '29', '25', '3', '2']
# ['2', '3', '5', '29', '29', '25', '3', '2']
# ['2', '29', '29', '2']
# ['3', '5', '11', '29', '29', '11', '7', '3']
# ['3', '5', '11', '29', '29', '21', '12', '3']
# ['3', '5', '29', '29', '5', '3']
# ['3', '5', '29', '29', '5', '3']
# ['3', '5', '29', '29', '5', '3']
# ['3', '5', '29', '29', '5', '3']
# ['3', '5', '29', '29', '5', '3']
# ['3', '29', '29', '3']
# ['4', '11', '29', '29', '11', '4']
# ['4', '11', '29', '29', '11', '4']
# ['4', '5', '11', '29', '29', '11', '9', '4']
# ['4', '5', '29', '29', '5', '4']
# ['4', '5', '29', '29', '5', '4']
# ['4', '5', '29', '29', '5', '4']
# ['4', '5', '29', '29', '5', '4']
# ['4', '5', '29', '29', '5', '4']
# ['4', '25', '29', '29', '2', '4']
# ['5', '11', '29', '29', '11', '5']
# ['5', '11', '29', '29', '11', '5']
# ['5', '11', '29', '29', '11', '5']
# ['5', '29', '29', '5']
# ['5', '29', '29', '5']
# ['5', '29', '29', '5']
# ['5', '29', '29', '5']
# ['5', '29', '29', '5']
# ['5', '29', '29', '5']
# ['6', '11', '29', '29', '11', '6']
# ['6', '11', '29', '29', '11', '6']
# ['6', '11', '29', '29', '11', '6']
# ['6', '11', '29', '29', '11', '6']
# ['6', '11', '29', '29', '11', '6']
# ['6', '11', '29', '29', '11', '6']
# ['6', '11', '29', '29', '11', '6']
# ['6', '5', '29', '29', '20', '6']
# ['6', '5', '29', '29', '20', '6']
# ['7', '11', '29', '29', '11', '7']
# ['7', '11', '29', '29', '11', '7']
# ['7', '11', '29', '29', '11', '7']
# ['7', '11', '29', '29', '11', '7']
# ['7', '11', '29', '29', '11', '7']
# ['7', '11', '29', '29', '11', '7']
# ['7', '11', '29', '29', '11', '7']
# ['7', '11', '29', '29', '11', '7']
# ['7', '11', '29', '29', '11', '7']
# ['8', '17', '29', '29', '17', '8']
# ['8', '17', '29', '29', '17', '8']
# ['8', '17', '29', '29', '17', '8']
# ['8', '17', '29', '29', '17', '8']
# ['8', '17', '29', '29', '17', '8']
# ['8', '17', '29', '29', '17', '8']
# ['8', '17', '29', '29', '17', '8']
# ['8', '29', '29', '8']
# ['8', '29', '29', '8']
# ['9', '17', '29', '29', '17', '9']
# ['9', '17', '29', '29', '17', '9']
# ['9', '17', '29', '29', '17', '9']
# ['9', '17', '29', '29', '17', '9']
# ['9', '17', '29', '29', '17', '9']
# ['9', '17', '29', '29', '17', '9']
# ['9', '17', '29', '29', '24', '9']
# ['9', '17', '29', '29', '24', '9']
# ['9', '17', '29', '29', '24', '9']
# ['10', '11', '29', '29', '11', '10']
# ['10', '11', '29', '29', '11', '10']
# ['10', '11', '29', '29', '20', '10']
# ['10', '11', '29', '29', '20', '10']
# ['10', '11', '29', '29', '20', '10']
# ['10', '11', '29', '29', '20', '10']
# ['10', '29', '29', '10']
# ['10', '29', '29', '10']
# ['10', '29', '29', '10']
# ['11', '29', '29', '11']
# ['11', '29', '29', '11']
# ['11', '29', '29', '11']
# ['11', '29', '29', '11']
# ['11', '29', '29', '11']
# ['11', '29', '29', '11']
# ['11', '29', '29', '11']
# ['11', '29', '29', '11']
# ['11', '29', '29', '11']
# ['12', '26', '29', '29', '21', '12']
# ['12', '26', '29', '29', '21', '12']
# ['12', '26', '29', '29', '21', '12']
# ['12', '26', '29', '29', '21', '12']
# ['12', '26', '29', '29', '21', '12']
# ['12', '26', '29', '29', '21', '12']
# ['12', '26', '29', '29', '21', '12']
# ['12', '26', '29', '29', '21', '12']
# ['12', '26', '29', '29', '21', '12']
# ['13', '26', '29', '29', '24', '13']
# ['13', '26', '29', '29', '24', '13']
# ['13', '26', '29', '29', '24', '13']
# ['13', '26', '29', '29', '24', '13']
# ['13', '29', '29', '13']
# ['13', '29', '29', '13']
# ['13', '29', '29', '13']
# ['13', '29', '29', '13']
# ['13', '29', '29', '13']
# ['14', '20', '29', '29', '19', '14']
# ['14', '20', '29', '29', '19', '14']
# ['14', '20', '29', '29', '19', '14']
# ['14', '29', '29', '14']
# ['14', '29', '29', '14']
# ['14', '29', '29', '14']
# ['14', '29', '29', '14']
# ['14', '24', '29', '29', '19', '14']
# ['15', '20', '29', '29', '25', '15']
# ['15', '20', '29', '29', '25', '15']
# ['15', '20', '29', '29', '25', '15']
# ['15', '29', '29', '15']
# ['15', '24', '29', '29', '25', '15']
# ['15', '24', '29', '29', '25', '15']
# ['15', '24', '29', '29', '25', '15']
# ['15', '24', '29', '29', '25', '15']
# ['16', '29', '29', '16']
# ['16', '29', '29', '16']
# ['16', '29', '29', '16']
# ['16', '29', '29', '16']
# ['16', '25', '29', '29', '24', '16']
# ['16', '25', '29', '29', '24', '16']
# ['16', '25', '29', '29', '24', '16']
# ['16', '25', '29', '29', '24', '16']
# ['17', '29', '29', '17']
# ['17', '29', '29', '17']
# ['17', '29', '29', '17']
# ['17', '29', '29', '17']
# ['17', '29', '29', '17']
# ['17', '29', '29', '17']
# ['17', '29', '29', '17']
# ['17', '29', '29', '17']
# ['17', '29', '29', '17']
# ['18', '29', '29', '18']
# ['18', '29', '29', '18']
# ['18', '29', '29', '18']
# ['18', '29', '29', '18']
# ['18', '29', '29', '18']
# ['18', '29', '29', '18']
# ['18', '29', '29', '18']
# ['18', '29', '29', '18']
# ['18', '29', '29', '18']
# ['19', '29', '29', '19']
# ['19', '29', '29', '19']
# ['19', '29', '29', '19']
# ['19', '29', '29', '19']
# ['19', '29', '29', '19']
# ['19', '29', '29', '19']
# ['19', '29', '29', '19']
# ['19', '29', '29', '19']
